# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# shortcut to set the max rows that will show.
def set_max_rows(max_rows=20):
    pd.set_option('display.max_rows', max_rows)
set_max_rows()

# %% [markdown]
# # Discovering The Dataset

# %%
# load the udemy courses dataset.
udemy_courses = pd.read_csv('original_udemy_courses.csv')

# %%
# show the info of the dataset to see what the features i have and how many null values there.
udemy_courses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9932 entries, 0 to 9931
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            9932 non-null   int64
#  1   title                         9932 non-null   object
#  2   url                           9932 non-null   object
#  3   is_paid                       9932 non-null   bool
#  4   num_subscribers               9932 non-null   int64
#  5   avg_rating                    9932 non-null   float64
#  6   avg_rating_recent             9932 non-null   float64
#  7   rating                        9932 non-null   float64
#  8   num_reviews                   9932 non-null   int64
#  9   num_published_lectures        9932 non-null   int64
#  10  num_published_practice_tests  9932 non-null   int64
#  11  created                       9932 non-null   object
#  12  published_time                9932 non-null   object
#  13  discount_price_amount         9764 non-null   float64
#  14  discount_price_currency       9764 non-null   object
#  15  price_detail_amount           9932 non-null   int64
#  16  price_detail_currency         9932 non-null   object
# dtypes: bool(1), float64(4), int64(6), object(6)
# memory usage: 1.2+ MB

# %%
# show the aggregate functions to see how the dataset look.
udemy_courses.describe()
# Out:
#                  id  num_subscribers   avg_rating  avg_rating_recent  \
# count  9.932000e+03     9.932000e+03  9932.000000        9932.000000
# mean   1.579035e+06     7.410613e+03     4.072721           4.055958
# std    8.361819e+05     2.589134e+04     0.496794           0.523469
# min    8.082000e+03     2.000000e+01     1.400000           1.337300
# 25%    9.287770e+05     3.750000e+02     3.800000           3.774955
# 50%    1.537401e+06     1.731000e+03     4.175220           4.166985
# 75%    2.242264e+06     5.739000e+03     4.437500           4.438873
# max    3.473846e+06     1.086954e+06     5.000000           5.000000
#
#             rating    num_reviews  num_published_lectures  \
# count  9932.000000    9932.000000             9932.000000
# mean      4.055958     687.041986               61.520842
# std       0.523469    5450.095041               71.216428
# min       1.337300       8.000000                0.000000
# 25%       3.774955      24.000000               22.000000
# 50%       4.166985      60.000000               39.000000
# 75%       4.438873     212.000000               72.000000
# max       5.000000  314098.000000              779.000000
#
#        num_published_practice_tests  discount_price_amount  \
# count                   9932.000000            9764.000000
# mean                       0.037857             466.730234
# std                        0.350750             146.976860
# min                        0.000000             455.000000
# 25%                        0.000000             455.000000
# 50%                        0.000000             455.000000
# 75%                        0.000000             455.000000
# max                        6.000000            3200.000000
#
#        price_detail_amount
# count          9932.000000
# mean           5254.321385
# std            3112.627009
# min            1280.000000
# 25%            1600.000000
# 50%            6080.000000
# 75%            8640.000000
# max           12800.000000

# %%
# this function is a shortcut to set the figure to specific size with seaborn.
def set_fig_size(size=(15,8)):
    sns.set(rc = {'figure.figsize':size})

# this function is a shortcut to show boxplot with specific size with seaborn.
def show_boxplot(data, size=(26,8)):
    set_fig_size(size)
    sns.boxplot(data=data)
    

show_boxplot(udemy_courses)

# %%
#### show the first 20 courses to discover more about the dataset.
udemy_courses.head(20)
# Out:
#          id                                              title  \
# 0    567828  2020 Complete Python Bootcamp: From Zero to He...
# 1    625204                         The Web Developer Bootcamp
# 2    950390  Machine Learning A-Z™: Hands-On Python & R In ...
# 3    756150        Angular - The Complete Guide (2020 Edition)
# 4    533682  Java Programming Masterclass for Software Deve...
# 5   1362070  React - The Complete Guide (incl Hooks, React ...
# 6    903744  Python for Data Science and Machine Learning B...
# 7   1565838         The Complete 2020 Web Development Bootcamp
# 8    851712  The Complete JavaScript Course 2020: Build Rea...
# 9    258316                Complete C# Unity Game Developer 2D
# 10  1754098  The Data Science Course 2020: Complete Data Sc...
# 11   543600  Automate the Boring Stuff with Python Programming
# 12   764164              The Complete Web Developer Course 2.0
# 13   705264              Modern React with Redux [2020 Update]
# 14   629302               Learn Python Programming Masterclass
# 15   922484  The Complete Node.js Developer Course (3rd Edi...
# 16   354176  Selenium WebDriver with Java -Basics to Advanc...
# 17  1778502  iOS 13 & Swift 5 - The Complete iOS App Develo...
# 18   657932  Unreal Engine C++ Developer: Learn C++ and Mak...
# 19   647428  Spring & Hibernate for Beginners (includes Spr...
#
#                                                   url  is_paid  \
# 0                   /course/complete-python-bootcamp/     True
# 1                 /course/the-web-developer-bootcamp/     True
# 2                            /course/machinelearning/     True
# 3            /course/the-complete-guide-to-angular-2/     True
# 4    /course/java-the-complete-java-developer-course/     True
# 5        /course/react-the-complete-guide-incl-redux/     True
# 6   /course/python-for-data-science-and-machine-le...     True
# 7      /course/the-complete-web-development-bootcamp/     True
# 8             /course/the-complete-javascript-course/     True
# 9                                /course/unitycourse/     True
# 10  /course/the-data-science-course-complete-data-...     True
# 11                                  /course/automate/     True
# 12       /course/the-complete-web-developer-course-2/     True
# 13                               /course/react-redux/     True
# 14  /course/python-the-complete-python-developer-c...     True
# 15    /course/the-complete-nodejs-developer-course-2/     True
# 16  /course/selenium-real-time-examplesinterview-q...     True
# 17           /course/ios-13-app-development-bootcamp/     True
# 18                              /course/unrealcourse/     True
# 19                 /course/spring-hibernate-tutorial/     True
#
#     num_subscribers  avg_rating  avg_rating_recent   rating  num_reviews  \
# 0           1086954     4.56326            4.56743  4.56743       314098
# 1            592474     4.64777            4.65291  4.65291       181621
# 2            687330     4.55210            4.54932  4.54932       131007
# 3            417746     4.57687            4.58594  4.58594       128705
# 4            497195     4.56571            4.57203  4.57203       122306
# 5            298871     4.61359            4.61924  4.61924        89164
# 6            383073     4.58310            4.59310  4.59310        86226
# 7            260968     4.69824            4.69833  4.69833        84386
# 8            343599     4.57355            4.57140  4.57140        82317
# 9            362891     4.64109            4.64056  4.64056        78378
# 10           320039     4.51932            4.51492  4.51492        75419
# 11           690595     4.62689            4.62567  4.62567        69172
# 12           272270     4.51663            4.51896  4.51896        62816
# 13           200683     4.65588            4.66017  4.66017        60156
# 14           234421     4.54662            4.54786  4.54786        57034
# 15           200500     4.67640            4.68391  4.68391        50192
# 16           146059     4.59904            4.60022  4.60022        49122
# 17           176051     4.75318            4.75110  4.75110        48932
# 18           227065     4.55991            4.55374  4.55374        45338
# 19           175140     4.59842            4.60719  4.60719        44712
#
#     num_published_lectures  num_published_practice_tests  \
# 0                      152                             0
# 1                      405                             0
# 2                      323                             0
# 3                      455                             0
# 4                      400                             0
# 5                      490                             0
# 6                      165                             0
# 7                      469                             0
# 8                      166                             0
# 9                      215                             0
# 10                     471                             0
# 11                      51                             0
# 12                     308                             0
# 13                     542                             0
# 14                     404                             0
# 15                     177                             0
# 16                     360                             0
# 17                     574                             0
# 18                     220                             0
# 19                     560                             0
#
#                  created        published_time  discount_price_amount  \
# 0   2015-07-29T00:12:23Z  2015-10-12T21:42:53Z                  455.0
# 1   2015-09-28T21:32:19Z  2015-11-02T21:13:27Z                  455.0
# 2   2016-09-05T09:54:22Z  2016-09-13T21:43:44Z                  455.0
# 3   2016-02-08T17:02:55Z  2016-02-11T07:29:29Z                  462.0
# 4   2015-06-21T20:25:56Z  2015-07-21T22:01:13Z                  455.0
# 5   2017-09-26T22:20:24Z  2017-10-24T22:03:07Z                  455.0
# 6   2016-07-13T05:22:58Z  2016-09-18T17:36:23Z                  462.0
# 7   2018-02-22T12:02:33Z  2018-10-25T21:34:15Z                  455.0
# 8   2016-05-17T09:31:26Z  2016-10-14T22:52:23Z                  455.0
# 9   2014-07-09T19:17:28Z  2014-09-03T19:30:05Z                  481.0
# 10  2018-06-18T12:30:08Z  2018-06-21T21:27:03Z                  494.0
# 11  2015-07-02T23:31:01Z  2015-09-21T21:10:01Z                  455.0
# 12  2016-02-16T09:09:40Z  2016-03-08T22:28:36Z                  455.0
# 13  2015-12-23T21:40:24Z  2015-12-28T19:20:21Z                  455.0
# 14  2015-10-03T01:45:17Z  2015-11-06T18:04:11Z                  455.0
# 15  2016-08-03T18:37:40Z  2016-10-04T15:27:39Z                  455.0
# 16  2014-11-23T02:38:12Z  2014-11-25T04:23:50Z                  462.0
# 17  2018-07-02T18:03:42Z  2018-08-06T11:46:44Z                  481.0
# 18  2015-11-02T17:09:54Z  2015-11-03T21:08:06Z                  455.0
# 19  2015-10-22T01:18:24Z  2016-05-27T19:56:06Z                  455.0
#
#    discount_price_currency  price_detail_amount price_detail_currency
# 0                      INR                 8640                   INR
# 1                      INR                 8640                   INR
# 2                      INR                 8640                   INR
# 3                      INR                 8640                   INR
# 4                      INR                 8640                   INR
# 5                      INR                 8640                   INR
# 6                      INR                 8640                   INR
# 7                      INR                 8640                   INR
# 8                      INR                 8640                   INR
# 9                      INR                 8960                   INR
# 10                     INR                 9280                   INR
# 11                     INR                 3200                   INR
# 12                     INR                 8640                   INR
# 13                     INR                 8640                   INR
# 14                     INR                 8640                   INR
# 15                     INR                 5440                   INR
# 16                     INR                 8640                   INR
# 17                     INR                 8960                   INR
# 18                     INR                 8640                   INR
# 19                     INR                 8640                   INR

# %%
# show the last 20 courses to discover more about the dataset.
udemy_courses.tail(20)
# Out:
#            id                                              title  \
# 9912  1427948      Spring 5.0 Project: Building a Travel Website
# 9913  3069064    A Practical Guide To Learn Angular From Scratch
# 9914  2328254  How to Import and Export Data in SQL Server (H...
# 9915  3138552     Game Audio 101: How to Create Sounds for Games
# 9916   830430                         Zero To Hero: Apache Maven
# 9917   662650  Native Android 101: A Quickstart to Building A...
# 9918  2304934                Machine Learning Projects with Java
# 9919  2412354  Introduction to Node js for beginners + game p...
# 9920  1115132            XML XQuery - Crash Course for Beginners
# 9921  2086360                                 Professional Swift
# 9922  1004324                    .NET Developer Skills Advancing
# 9923   987724  Building 3D Voxel Art Environment Worlds with ...
# 9924  1915066       Start Your Freelance Career on PeopleperHour
# 9925  1958072             CSS3 Crash Course in Less than 3 Hours
# 9926  1963846  AI Academy #1: Learn Regression Analysis Metho...
# 9927  2491260              Simple image classification using KNN
# 9928  2533542                            Spring AOP Crash Course
# 9929  2552283  Google Chrome Extensions | Create Awesome Exte...
# 9930    96808              Advanced Java Programming (Java SE 7)
# 9931  1783958  Master Series: Build Models & Games in Unity &...
#
#                                                     url  is_paid  \
# 9912  /course/spring-50-project-building-a-travel-we...     True
# 9913  /course/a-practical-guide-to-learn-angular-fro...     True
# 9914         /course/how-import-export-data-sql-server/     True
# 9915                              /course/gameaudio101/     True
# 9916                 /course/zero-to-hero-apache-maven/     True
# 9917                        /course/native-android-101/     True
# 9918       /course/machine-learning-projects-with-java/     True
# 9919                               /course/node-course/     True
# 9920     /course/xml-xquery-crash-course-for-beginners/     True
# 9921                        /course/professional-swift/     True
# 9922                      /course/net-developer-skills/     True
# 9923  /course/3d-voxel-art-building-environment-worl...     True
# 9924  /course/start-your-freelance-career-on-peoplep...     True
# 9925    /course/css3-crash-course-in-less-than-3-hours/     True
# 9926  /course/artificial-intelligence-masterclass1re...     True
# 9927     /course/simple-image-classification-using-knn/     True
# 9928                   /course/spring-aop-crash-course/     True
# 9929                  /course/google-chrome-extensions/     True
# 9930   /course/advanced-java-programming-java-se-7-vtc/     True
# 9931                          /course/unityblender2d3d/     True
#
#       num_subscribers  avg_rating  avg_rating_recent   rating  num_reviews  \
# 9912               69     3.38889            3.48542  3.48542            9
# 9913             2667     3.38889            3.52495  3.52495            9
# 9914               55     4.50000            4.28595  4.28595            9
# 9915               49     4.94444            4.98540  4.98540            9
# 9916              416     3.72222            3.72022  3.72022            9
# 9917               25     3.88889            3.98884  3.98884            9
# 9918               43     3.38889            3.35514  3.35514            9
# 9919             2130     4.27778            4.58629  4.58629            9
# 9920              458     3.11111            2.89194  2.89194            9
# 9921               70     4.16667            4.05770  4.05770            9
# 9922              146     3.43750            3.46517  3.46517            8
# 9923              787     3.18750            2.88467  2.88467            8
# 9924              103     3.31250            2.47831  2.47831            8
# 9925             2618     3.43750            3.53148  3.53148            8
# 9926             2104     3.06250            3.40520  3.40520            8
# 9927               36     4.06250            3.90201  3.90201            8
# 9928             1404     3.25000            3.00652  3.00652            8
# 9929               75     4.25000            4.12268  4.12268            8
# 9930               80     3.50000            3.42335  3.42335            8
# 9931              237     4.06250            4.08441  4.08441            8
#
#       num_published_lectures  num_published_practice_tests  \
# 9912                      25                             0
# 9913                       7                             0
# 9914                      22                             1
# 9915                      22                             0
# 9916                      36                             0
# 9917                      27                             0
# 9918                      24                             0
# 9919                      42                             0
# 9920                      10                             0
# 9921                      54                             0
# 9922                      24                             0
# 9923                      16                             0
# 9924                      26                             0
# 9925                      36                             0
# 9926                      41                             0
# 9927                      15                             0
# 9928                      29                             0
# 9929                      53                             0
# 9930                     103                             0
# 9931                     152                             0
#
#                    created        published_time  discount_price_amount  \
# 9912  2017-11-10T10:11:35Z  2017-11-16T06:14:08Z                  455.0
# 9913  2020-04-29T18:47:06Z  2020-05-07T02:59:08Z                  455.0
# 9914  2019-04-18T15:48:28Z  2019-04-24T01:51:40Z                  455.0
# 9915  2020-05-17T14:07:44Z  2020-05-22T17:02:36Z                  960.0
# 9916  2016-04-24T05:23:48Z  2016-04-26T01:06:11Z                  455.0
# 9917  2015-11-07T02:14:59Z  2016-01-12T18:01:44Z                    NaN
# 9918  2019-04-03T09:02:00Z  2019-04-04T17:40:16Z                  455.0
# 9919  2019-06-13T18:15:32Z  2019-06-24T19:25:02Z                  455.0
# 9920  2017-02-15T09:04:37Z  2017-02-19T22:52:36Z                  455.0
# 9921  2018-12-14T09:57:53Z  2018-12-19T02:24:45Z                  455.0
# 9922  2016-11-06T07:39:55Z  2016-12-29T22:48:10Z                  455.0
# 9923  2016-10-18T15:18:54Z  2016-10-18T22:46:59Z                  455.0
# 9924  2018-09-16T08:02:12Z  2018-09-18T02:41:26Z                  455.0
# 9925  2018-10-10T09:58:24Z  2018-12-06T15:54:50Z                  455.0
# 9926  2018-10-13T07:17:25Z  2018-10-22T13:18:13Z                  455.0
# 9927  2019-08-02T22:47:25Z  2019-08-13T22:40:09Z                  455.0
# 9928  2019-08-29T11:49:22Z  2019-08-30T21:30:11Z                  455.0
# 9929  2019-09-10T08:02:09Z  2020-01-30T20:39:08Z                  455.0
# 9930  2013-09-24T21:18:14Z  2013-10-04T13:34:06Z                    NaN
# 9931  2018-07-05T17:00:45Z  2018-07-11T21:11:18Z                  455.0
#
#      discount_price_currency  price_detail_amount price_detail_currency
# 9912                     INR                 8000                   INR
# 9913                     INR                 8640                   INR
# 9914                     INR                 5120                   INR
# 9915                     INR                 3840                   INR
# 9916                     INR                 2240                   INR
# 9917                     NaN                 1600                   INR
# 9918                     INR                 8000                   INR
# 9919                     INR                 1280                   INR
# 9920                     INR                 8320                   INR
# 9921                     INR                 8640                   INR
# 9922                     INR                 8640                   INR
# 9923                     INR                 6400                   INR
# 9924                     INR                 1920                   INR
# 9925                     INR                 1280                   INR
# 9926                     INR                 8640                   INR
# 9927                     INR                 1280                   INR
# 9928                     INR                 1280                   INR
# 9929                     INR                 6400                   INR
# 9930                     NaN                 2560                   INR
# 9931                     INR                 8640                   INR

# %%
# see what the null values "discount_price__amount" represents.
discount_amount_null_mask = udemy_courses['discount_price_amount'].isna()
udemy_courses[discount_amount_null_mask]
# Out:
#            id                                              title  \
# 146   1080408  Artificial Intelligence: Reinforcement Learnin...
# 177    918390  Natural Language Processing with Deep Learning...
# 228   1141808                 Build+Deploy+Test with Jenkins 2.0
# 292   1153742  Advanced AI: Deep Reinforcement Learning in Py...
# 605   1022582                Vue.js Essentials - 3 Course Bundle
# ...       ...                                                ...
# 9766  1667778                     JAVA Immersive Learning Course
# 9826    17492                       Introduction to SQL Training
# 9851  2047757                         Servicenow ITOM -Discovery
# 9917   662650  Native Android 101: A Quickstart to Building A...
# 9930    96808              Advanced Java Programming (Java SE 7)
#
#                                                     url  is_paid  \
# 146   /course/artificial-intelligence-reinforcement-...     True
# 177   /course/natural-language-processing-with-deep-...     True
# 228                       /course/working-with-jenkins/     True
# 292      /course/deep-reinforcement-learning-in-python/     True
# 605                         /course/vuejs-2-essentials/     True
# ...                                                 ...      ...
# 9766            /course/java-immersive-learning-course/     True
# 9826                      /course/introduction-to-sql3/     True
# 9851                       /course/servicenowdiscovery/     True
# 9917                        /course/native-android-101/     True
# 9930   /course/advanced-java-programming-java-se-7-vtc/     True
#
#       num_subscribers  avg_rating  avg_rating_recent   rating  num_reviews  \
# 146             38754     4.65859            4.61036  4.61036         7705
# 177             37638     4.63293            4.55637  4.55637         5952
# 228             67732     4.23438            4.23861  4.23861         4620
# 292             31790     4.56197            4.55692  4.55692         3437
# 605              7159     4.55814            4.59968  4.59968         1501
# ...               ...         ...                ...      ...          ...
# 9766               93     4.92857            4.91545  4.91545           22
# 9826              305     4.55000            4.54834  4.54834           15
# 9851               30     3.45000            3.34174  3.34174           13
# 9917               25     3.88889            3.98884  3.98884            9
# 9930               80     3.50000            3.42335  3.42335            8
#
#       num_published_lectures  num_published_practice_tests  \
# 146                      107                             0
# 177                       95                             0
# 228                       50                             0
# 292                       79                             0
# 605                      182                             0
# ...                      ...                           ...
# 9766                     115                             0
# 9826                      55                             0
# 9851                       5                             1
# 9917                      27                             0
# 9930                     103                             0
#
#                    created        published_time  discount_price_amount  \
# 146   2017-01-17T22:57:25Z  2017-01-27T18:43:16Z                    NaN
# 177   2016-07-30T01:59:11Z  2016-08-09T00:06:54Z                    NaN
# 228   2017-03-11T04:51:39Z  2017-03-21T00:35:01Z                    NaN
# 292   2017-03-22T07:07:14Z  2017-03-24T20:58:09Z                    NaN
# 605   2016-11-25T06:22:40Z  2016-12-16T14:59:21Z                    NaN
# ...                    ...                   ...                    ...
# 9766  2018-04-29T04:11:09Z  2018-05-29T17:18:34Z                    NaN
# 9826  2012-05-09T18:12:08Z  2012-05-15T17:51:15Z                    NaN
# 9851  2018-11-25T17:15:02Z  2019-10-20T20:42:34Z                    NaN
# 9917  2015-11-07T02:14:59Z  2016-01-12T18:01:44Z                    NaN
# 9930  2013-09-24T21:18:14Z  2013-10-04T13:34:06Z                    NaN
#
#      discount_price_currency  price_detail_amount price_detail_currency
# 146                      NaN                 1920                   INR
# 177                      NaN                 1920                   INR
# 228                      NaN                 1920                   INR
# 292                      NaN                 1920                   INR
# 605                      NaN                 6400                   INR
# ...                      ...                  ...                   ...
# 9766                     NaN                 3200                   INR
# 9826                     NaN                 3200                   INR
# 9851                     NaN                 2560                   INR
# 9917                     NaN                 1600                   INR
# 9930                     NaN                 2560                   INR
#
# [168 rows x 17 columns]

# %%
# check if is there any course its "discount_price__amount" equal  to zero
discount_amount_zero_mask = udemy_courses['discount_price_amount'] == 0
udemy_courses[discount_amount_zero_mask]
# Out:
# Empty DataFrame
# Columns: [id, title, url, is_paid, num_subscribers, avg_rating, avg_rating_recent, rating, num_reviews, num_published_lectures, num_published_practice_tests, created, published_time, discount_price_amount, discount_price_currency, price_detail_amount, price_detail_currency]
# Index: []

# %%
# check what the type of "created" column
type(udemy_courses['created'][0])
# Out:
# str

# %%
# check what the type of "published_time" column
type(udemy_courses['published_time'][0])
# Out:
# str

# %%
# see is all courses is paid
udemy_courses['is_paid'].value_counts()
# Out:
# True    9932
# Name: is_paid, dtype: int64

# %%
# show the first 20 courses,
# and see what the difference between "title" and "url" columns and how represents the name of the course
udemy_courses[['title', 'url']].head(20)
# Out:
#                                                 title  \
# 0   2020 Complete Python Bootcamp: From Zero to He...
# 1                          The Web Developer Bootcamp
# 2   Machine Learning A-Z™: Hands-On Python & R In ...
# 3         Angular - The Complete Guide (2020 Edition)
# 4   Java Programming Masterclass for Software Deve...
# 5   React - The Complete Guide (incl Hooks, React ...
# 6   Python for Data Science and Machine Learning B...
# 7          The Complete 2020 Web Development Bootcamp
# 8   The Complete JavaScript Course 2020: Build Rea...
# 9                 Complete C# Unity Game Developer 2D
# 10  The Data Science Course 2020: Complete Data Sc...
# 11  Automate the Boring Stuff with Python Programming
# 12              The Complete Web Developer Course 2.0
# 13              Modern React with Redux [2020 Update]
# 14               Learn Python Programming Masterclass
# 15  The Complete Node.js Developer Course (3rd Edi...
# 16  Selenium WebDriver with Java -Basics to Advanc...
# 17  iOS 13 & Swift 5 - The Complete iOS App Develo...
# 18  Unreal Engine C++ Developer: Learn C++ and Mak...
# 19  Spring & Hibernate for Beginners (includes Spr...
#
#                                                   url
# 0                   /course/complete-python-bootcamp/
# 1                 /course/the-web-developer-bootcamp/
# 2                            /course/machinelearning/
# 3            /course/the-complete-guide-to-angular-2/
# 4    /course/java-the-complete-java-developer-course/
# 5        /course/react-the-complete-guide-incl-redux/
# 6   /course/python-for-data-science-and-machine-le...
# 7      /course/the-complete-web-development-bootcamp/
# 8             /course/the-complete-javascript-course/
# 9                                /course/unitycourse/
# 10  /course/the-data-science-course-complete-data-...
# 11                                  /course/automate/
# 12       /course/the-complete-web-developer-course-2/
# 13                               /course/react-redux/
# 14  /course/python-the-complete-python-developer-c...
# 15    /course/the-complete-nodejs-developer-course-2/
# 16  /course/selenium-real-time-examplesinterview-q...
# 17           /course/ios-13-app-development-bootcamp/
# 18                              /course/unrealcourse/
# 19                 /course/spring-hibernate-tutorial/

# %% [markdown]
# ---
#
# ### I Discovered the following:
# - rating column is duplicte of avg_rating_recent column.
# - the currency that used in the data INR (INR is Indian currency).
# - the nan values that in "discount_price__amount" and "discount_price__currency" columns are represents that there is no discount in that course.
# - the date and time in the dataset are string.
# - all courses in the dataset is paid.
# - there some columns have outliers.
#
# ### Actions I will take to prepare and clean the data:
# I will create new data frame that has the same dataset with the following differences:
# - remove (url, avg_rating_recent, rating, created, published_time, discount_price_currency, price_detail_currency) columns, they didn't give any useful info about the analysis.
# - create new column its name is "year", and it will have only the year of "published_time".
# - convert the INR currency to SR, and make it only one column, its name is currency.
# - replace the nan values in "discount_price__amount" column to 0.
# - add new columns that will have keywords based on title filtering to make the analysis easier.
# - clean the outliers.

# %%
# copy the [id, title] columns from the original dataset.
cleaned_courses = udemy_courses[['id', 'title']].copy()

# remove the extra whitespaces on the edges from the title column.
cleaned_courses['title'] = cleaned_courses['title'].str.strip()

cleaned_courses
# Out:
#            id                                              title
# 0      567828  2020 Complete Python Bootcamp: From Zero to He...
# 1      625204                         The Web Developer Bootcamp
# 2      950390  Machine Learning A-Z™: Hands-On Python & R In ...
# 3      756150        Angular - The Complete Guide (2020 Edition)
# 4      533682  Java Programming Masterclass for Software Deve...
# ...       ...                                                ...
# 9927  2491260              Simple image classification using KNN
# 9928  2533542                            Spring AOP Crash Course
# 9929  2552283  Google Chrome Extensions | Create Awesome Exte...
# 9930    96808              Advanced Java Programming (Java SE 7)
# 9931  1783958  Master Series: Build Models & Games in Unity &...
#
# [9932 rows x 2 columns]

# %%
# copy the [num_subscribers,avg_rating,num_reviews,num_published_lectures,num_published_practice_tests]_
# _columns from the original dataset.
cleaned_courses[['num_subscribers',
                 'avg_rating',
                 'num_reviews',
                 'num_lectures',
                 'num_practice_tests']] = udemy_courses[['num_subscribers',
                                                                   'avg_rating',
                                                                   'num_reviews',
                                                                   'num_published_lectures',
                                                                   'num_published_practice_tests']].copy()

# %%
# convert the published_time column from original dataset to Timestamp and get the years 
# and add them to year column into the new dataset.
published_time = pd.to_datetime(udemy_courses['published_time'])
cleaned_courses['year'] = published_time.apply(lambda time: time.year)

# %%
# this is the factor to convert INR amount to SR amount.
sr_factor = 0.050

# copy (price and discount) amounts columns and rename them.
amounts = udemy_courses[['price_detail_amount', 'discount_price_amount']].copy()
new_names = {'price_detail_amount': 'price_amount', 'discount_price_amount': 'discount_amount'}
amounts = amounts.rename(columns=new_names)

# replace the discount nan values into 0
amounts.fillna(0, inplace=True)
# convert INR amounts into SR amounts.
amounts *= sr_factor

amounts
# Out:
#       price_amount  discount_amount
# 0            432.0            22.75
# 1            432.0            22.75
# 2            432.0            22.75
# 3            432.0            23.10
# 4            432.0            22.75
# ...            ...              ...
# 9927          64.0            22.75
# 9928          64.0            22.75
# 9929         320.0            22.75
# 9930         128.0             0.00
# 9931         432.0            22.75
#
# [9932 rows x 2 columns]

# %%
# apppend the (price, discount, cuurency) columns.
cleaned_courses[['price_amount', 'discount_amount']] = amounts[['price_amount', 'discount_amount']]
cleaned_courses['currency'] = 'SR'

# %%
cleaned_courses.head()
# Out:
#        id                                              title  num_subscribers  \
# 0  567828  2020 Complete Python Bootcamp: From Zero to He...          1086954
# 1  625204                         The Web Developer Bootcamp           592474
# 2  950390  Machine Learning A-Z™: Hands-On Python & R In ...           687330
# 3  756150        Angular - The Complete Guide (2020 Edition)           417746
# 4  533682  Java Programming Masterclass for Software Deve...           497195
#
#    avg_rating  num_reviews  num_lectures  num_practice_tests  year  \
# 0     4.56326       314098           152                   0  2015
# 1     4.64777       181621           405                   0  2015
# 2     4.55210       131007           323                   0  2016
# 3     4.57687       128705           455                   0  2016
# 4     4.56571       122306           400                   0  2015
#
#    price_amount  discount_amount currency
# 0         432.0            22.75       SR
# 1         432.0            22.75       SR
# 2         432.0            22.75       SR
# 3         432.0            23.10       SR
# 4         432.0            22.75       SR

# %%
# this method is for clean the outliers by set them to min and max ranges of specific column on the data frame.
def clean_outliers(df, target_column):
    column = df[target_column].copy()
    
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    
    min_range = Q1 - 1.5 * IQR
    max_range = Q3 + 1.5 * IQR
    
    min_outliers_mask = column < min_range
    max_outliers_mask = column > max_range
    
    column[min_outliers_mask] = min_range
    column[max_outliers_mask] = max_range
    
    return column

# %%
# show box plot before cleaning
show_boxplot(cleaned_courses)

# %%
# columns that will clean its outliers.
columns = ['num_subscribers',
           'avg_rating',
           'num_reviews',
           'num_lectures',
           'num_practice_tests',
           'discount_amount']

for column in columns:
    cleaned_courses[column] = clean_outliers(cleaned_courses, column)

# %%
# show box plot after cleaning
show_boxplot(cleaned_courses)

# %%
# this method add new column has the specific keywrods based on what the specific words in the title.
# keywords_dic: is a dictionary its key is keywrod and its value is the words the method will filter the title with.
# column_name: the column name that will be added to the data frame.
# after_col_pos: after what column the new column will be added, default is title.
def filter_title_keywrods(keywords_dic, column_name, after_col_pos='title'):
    cleaned_courses_copy = cleaned_courses.copy()
    keywords_dic = {keyword: "|".join(words) for keyword,words in keywords_dic.items()}
    cleaned_courses_copy[column_name] = [[] for e in range(len(cleaned_courses_copy))]
    
    for keyword in keywords_dic:
        keyword_mask = cleaned_courses_copy.title.str.contains(keywords_dic[keyword], case=False)
        cleaned_courses_copy.loc[keyword_mask, column_name].apply(lambda course: course.append(keyword))
        
    keyword_col = cleaned_courses_copy.pop(column_name)
    target_col_pos = cleaned_courses_copy.columns.get_loc(after_col_pos)
    cleaned_courses_copy.insert(target_col_pos+1, column_name, keyword_col)
    return cleaned_courses_copy




# this method gets the rows that its target column has the keywords.
# df: target data frame.
# keywords: the keywords that will filter rows by them.
# target_column: the column that will apply the filter on it.
def get_keywords_mask(df, keywords, target_column):
    filter_mask = None
    if type(keywords) == list:
        filter_mask = df[target_column].apply(
            lambda list_element: any([keyword in list_element for keyword in keywords]) )
    else:
        filter_mask = df[target_column].apply(lambda list_element: keywords in list_element)
        
    return df[filter_mask]



# this method gets unique values of the target column that its elements is lists.
# df: target data frame.
# target_column: target column.
def get_list_unique(df, target_column):
    unique_values = set()
    df[target_column].apply(lambda list_element: [unique_values.add(element) for element in list_element] )
    return pd.Series(list(unique_values))



# this method gets the data frame with the empty elements in the target column.
# df: target data frame.
# target_column: target column.
# reverse: if True it will return non_empty elements.
def get_empty_mask(df, target_column , reverse=False):
    empty_mask = df[target_column].str.len() == 0
    if reverse:
        return df[~empty_mask]
    else:
        return df[empty_mask]

# %%
# categories based on list of keywords.
categories = {
    'web': ['js', 'javascript', 'html', 'css', 'web', ' react ', 'angular', 'node', 'php', 'django', 'bootstrap', 'wordpress', 'ASP.NET', 'asp', 'AJAX', 'jquery'],
    'data science': ['google clouds', 'azure', 'AWS', 'data science', 'data analysis', 'python', ' R ', 'R ', 'statistics', 'jupyter', 'pandas', 'numpy', 'big data', 'data visualization'],
    'AI': ['python', 'machine', 'deep', 'AI', 'artificial', 'neural', 'classification', 'regression', 'natural language process', 'nlp'],
    'mobile': ['mobile', 'flutter', 'android', 'ios', 'react native', 'swift', 'dart', 'kotlin', ' app '],
    'python': ['python'],
    'javascript': ['js', 'javascript'],
    'java': ['java', 'spring'],
    'html': ['html'],
    'css': ['css'],
    'c#': ['c\#'],
    'cpp': ['c\+\+'],
    'go': [' go ', 'go ', 'go:'],
    'game development': ['unity', 'unreal', 'game'],
    'database': ['sql', 'mongodb', 'database', 'oracle', 'apache', 'firebase'],
    'software development tools': ['docker', 'git', 'kubernetes', 'devops', 'jira', 'jenkins']
}



# add new column called 'categories' and apply to the categories based on the specific keywrods in the title.
categorized_courses = filter_title_keywrods(categories, column_name='categories')

# fill the courses that not have any category with 'other' category.
others = get_empty_mask(categorized_courses, 'categories')
others.categories.apply(lambda categories: categories.append('other'))

categorized_courses.head()
# Out:
#        id                                              title  \
# 0  567828  2020 Complete Python Bootcamp: From Zero to He...
# 1  625204                         The Web Developer Bootcamp
# 2  950390  Machine Learning A-Z™: Hands-On Python & R In ...
# 3  756150        Angular - The Complete Guide (2020 Edition)
# 4  533682  Java Programming Masterclass for Software Deve...
#
#                    categories  num_subscribers  avg_rating  num_reviews  \
# 0  [data science, AI, python]            13785     4.56326          494
# 1         [web, data science]            13785     4.64777          494
# 2  [data science, AI, python]            13785     4.55210          494
# 3         [web, data science]            13785     4.57687          494
# 4        [data science, java]            13785     4.56571          494
#
#    num_lectures  num_practice_tests  year  price_amount  discount_amount  \
# 0           147                   0  2015         432.0            22.75
# 1           147                   0  2015         432.0            22.75
# 2           147                   0  2016         432.0            22.75
# 3           147                   0  2016         432.0            22.75
# 4           147                   0  2015         432.0            22.75
#
#   currency
# 0       SR
# 1       SR
# 2       SR
# 3       SR
# 4       SR

# %%
# show the final dataset info.
cleaned_courses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9932 entries, 0 to 9931
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  9932 non-null   int64
#  1   title               9932 non-null   object
#  2   num_subscribers     9932 non-null   int64
#  3   avg_rating          9932 non-null   float64
#  4   num_reviews         9932 non-null   int64
#  5   num_lectures        9932 non-null   int64
#  6   num_practice_tests  9932 non-null   int64
#  7   year                9932 non-null   int64
#  8   price_amount        9932 non-null   float64
#  9   discount_amount     9932 non-null   float64
#  10  currency            9932 non-null   object
# dtypes: float64(3), int64(6), object(2)
# memory usage: 853.7+ KB

# %% [markdown]
# ## Save the clean dataset into csv file:

# %%
# save the cleaned dataset to new csv file (uncomment the code below to save it).

cleaned_courses.to_csv('cleaned_udemy_courses.csv', index=False)
categorized_courses.to_csv('categorized_udemy_courses.csv', index=False)

# %% [markdown]
# ## Load the clean dataset:

# %%
# load the cleaned courses csv file.
cleaned_courses = pd.read_csv('cleaned_udemy_courses.csv')
categorized_courses = pd.read_csv('categorized_udemy_courses.csv')

cleaned_courses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9932 entries, 0 to 9931
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  9932 non-null   int64
#  1   title               9932 non-null   object
#  2   keywords            9932 non-null   object
#  3   num_subscribers     9932 non-null   int64
#  4   avg_rating          9932 non-null   float64
#  5   num_reviews         9932 non-null   int64
#  6   num_lectures        9932 non-null   int64
#  7   num_practice_tests  9932 non-null   int64
#  8   year                9932 non-null   int64
#  9   price_amount        9932 non-null   float64
#  10  discount_amount     9932 non-null   float64
#  11  currency            9932 non-null   object
# dtypes: float64(3), int64(6), object(3)
# memory usage: 931.2+ KB

# %%
categorized_courses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9932 entries, 0 to 9931
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  9932 non-null   int64
#  1   title               9932 non-null   object
#  2   categories          9932 non-null   object
#  3   num_subscribers     9932 non-null   int64
#  4   avg_rating          9932 non-null   float64
#  5   num_reviews         9932 non-null   int64
#  6   num_lectures        9932 non-null   int64
#  7   num_practice_tests  9932 non-null   int64
#  8   year                9932 non-null   int64
#  9   price_amount        9932 non-null   float64
#  10  discount_amount     9932 non-null   float64
#  11  currency            9932 non-null   object
# dtypes: float64(3), int64(6), object(3)
# memory usage: 931.2+ KB

# %% [markdown]
# # Filtering:

# %%
# gets data frame that contain every context in the target column associated with its data(year,count,...).
# df: target data frame.
# target_column: target column.
def contexts_stats(df, target_column):
    contexts_dic = {'context': [], 'year': [], 'courses_count': [],
                    'num_subscribers': [], 'min_price': [], 'max_price': [], 
                    'describe': []}
    
    contexts = get_list_unique(df, target_column)
    for context in contexts:
        context_df = get_keywords_mask(df, context, target_column)
        
        years = context_df['year'].value_counts().sort_index(ascending=False)
        for year in years.keys():
            contexts_dic['context'].append(context)
            contexts_dic['year'].append(year)
            contexts_dic['courses_count'].append(years[year])
    
            year_mask = context_df['year'] == year
    
            num_subscribers = context_df[year_mask].num_subscribers.sum()
            min_price = context_df[year_mask].price_amount.min()
            max_price = context_df[year_mask].price_amount.max()
            
            contexts_dic['num_subscribers'].append(num_subscribers)
            contexts_dic['min_price'].append(min_price)
            contexts_dic['max_price'].append(max_price)
            contexts_dic['describe'].append(context_df[year_mask].describe())
            
    return pd.DataFrame(contexts_dic)

# %% [markdown]
# ---

# %% [markdown]
# # Questions:

# %% [markdown]
# ### Question 1:
# what is the most development category that the users interested in?

# %%
categories_stats = contexts_stats(categorized_courses, 'categories')

target_year = 2020
categories_stats_in_year = categories_stats.query(
                            f"year == {target_year}").sort_values('num_subscribers', ascending=False)


categories_stats_in_year
# Out:
#                         context  year  courses_count  num_subscribers  \
# 30                 data science  2020            602          3039503
# 0                           web  2020            359          2099800
# 68                           AI  2020            285          1705719
# 105                      python  2020            187          1241823
# 20                         java  2020            125           830195
# 143                  javascript  2020            109           712607
# 10                        other  2020            117           387928
# 58                     database  2020             89           360963
# 86                       mobile  2020            108           323405
# 114                        html  2020             41           302445
# 48                          css  2020             35           245523
# 77             game development  2020             68           186412
# 40                           go  2020             30           157729
# 95                          cpp  2020             18           140149
# 133                          c#  2020             31           117172
# 124  software development tools  2020             37           112629
#
#      min_price  max_price                                           describe
# 30        64.0      480.0                   id  num_subscribers  avg_rati...
# 0         64.0      432.0                   id  num_subscribers  avg_rati...
# 68        64.0      640.0                   id  num_subscribers  avg_rati...
# 105       64.0      432.0                   id  num_subscribers  avg_rati...
# 20        64.0      432.0                   id  num_subscribers  avg_rati...
# 143       64.0      432.0                   id  num_subscribers  avg_rati...
# 10        64.0      432.0                   id  num_subscribers  avg_rati...
# 58        64.0      432.0                   id  num_subscribers  avg_rati...
# 86        64.0      432.0                   id  num_subscribers  avg_rati...
# 114       64.0      432.0                   id  num_subscribers  avg_rati...
# 48        64.0      432.0                   id  num_subscribers  avg_rati...
# 77        64.0      480.0                   id  num_subscribers  avg_rati...
# 40        64.0      432.0                   id  num_subscribers  avg_rati...
# 95        64.0      432.0                   id  num_subscribers  avg_rati...
# 133       64.0      432.0                   id  num_subscribers  avg_rati...
# 124       64.0      432.0                   id  num_subscribers  avg_rati...

# %%
set_fig_size((16,8))
sns.set(font_scale = 1.25)
stats_in_year_plot = sns.barplot(x='num_subscribers',y='context', data=categories_stats_in_year)


title = "(Udemy)\nusers interests in the development categories in 2020"
labels_font_size = 20
labels_color = 'r'

stats_in_year_plot.set_title(title, fontsize=30, color='b', y=1.05)
stats_in_year_plot.set_xlabel('subscribers', color=labels_color, fontsize=labels_font_size)
stats_in_year_plot.set_ylabel('category', color=labels_color, fontsize=labels_font_size)
# Out:
# Text(0, 0.5, 'category')

# %% [markdown]
# ### Answer 1:
# the most category the users interested in 2020 is the data science.

# %% [markdown]
# ---

# %% [markdown]
# ### Question 2:
# is the number of lectures make difference?

# %%
print( "Correlation: ", categorized_courses.corr().loc['num_subscribers', 'num_lectures'] )
sns.scatterplot(x='num_subscribers', y='num_lectures', data=categorized_courses);
# Out:
# Correlation:  0.1702094079737488

# %% [markdown]
# ### Answer 2:
# the relationship between the number of lectures and number of subscribers is low, so the number of lectures not making any difference of subscribing the users in the course.

# %% [markdown]
# ---

# %% [markdown]
# ### Question 3:
# is the courses has a "bootcamp" in their names has more subscribers?

# %%
keywords = {'bootcamp': ['bootcamp']}
bootcamp_taged_courses = filter_title_keywrods(keywords, 'tags')
non_bootcamp_taged_courses = get_empty_mask(bootcamp_taged_courses, 'tags')
bootcamp_taged_courses = get_keywords_mask(bootcamp_taged_courses, 'bootcamp', 'tags')

non_bootcamp_taged_courses['num_subscribers']
bootcamp_taged_courses['num_subscribers']

#TODO
#...
# Out:
# 0       13785
# 1       13785
# 6       13785
# 7       13785
# 10      13785
#         ...
# 9704     3529
# 9712      581
# 9778      301
# 9873      690
# 9897       37
# Name: num_subscribers, Length: 221, dtype: int64

# %% [markdown]
# ### Answer 3:
